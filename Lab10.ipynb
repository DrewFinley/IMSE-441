# %% [markdown]
# <a href="https://colab.research.google.com/github/DrewFinley/IMSE-441/blob/main/Lab10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

#statistic 
import scipy as scipy
from scipy import stats
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
#from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score

# %%
df = pd.read_csv('https://raw.githubusercontent.com/DrewFinley/IMSE-441/main/Lab10Data.csv')
df
# Out:
#       x    y  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0   1.6  240         NaN         NaN         NaN         NaN         NaN
# 1   9.4  181         NaN         NaN         NaN         NaN         NaN
# 2  15.5  193         NaN         NaN         NaN         NaN         NaN
# 3  20.0  155         NaN         NaN         NaN         NaN         NaN
# 4  22.0  172         NaN         NaN         NaN         NaN         NaN
# 5  35.5  110         NaN         NaN         NaN         NaN         NaN
# 6  43.0  113         NaN         NaN         NaN         NaN         NaN
# 7  40.5   75         NaN         NaN         NaN         NaN         NaN
# 8  33.0   94         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 7    x2     y2
# 0         NaN   8.0  122.0
# 1         NaN  10.0  132.0
# 2         NaN  12.0  145.0
# 3         NaN  14.0  161.0
# 4         NaN  16.0  178.0
# 5         NaN  18.0  190.0
# 6         NaN   NaN    NaN
# ...

# %%
plt.figure(figsize=(15,10))
plt.scatter(df['x'],df['y'])
plt.title('Oil Viscocity vs Wear Volume', fontsize= 20 )
plt.xlabel('Oil Viscocity', fontsize = 15)
plt.ylabel('Wear Volume', fontsize =15)
plt.show()
